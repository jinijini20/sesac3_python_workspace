# %% [markdown]
# # 3장 파이썬을 계산기처럼 이용하기
# ## 3.1 간단한 사칙 연산
# - 파이썬에서 사칙 연산을 하려면 더하기(+), 빼기(-), 곱하기(*), 나누기(/) 기호를 이용

# %%
1+1
# Out:
# 2

# %%
5-2
# Out:
# 3

# %% [markdown]
# ### 파이썬에서는 숫자와 연산자 사이의 공백은 무시하므로 이 공백은 있어도 되고 없어도 됨

# %%
15*2
# Out:
# 30

# %%
10/2
# Out:
# 5.0

# %% [markdown]
# ### 파이썬에서 나눗셈 연산은 실수로 처리하기 때문

# %%
1.2+5.3
# Out:
# 6.5

# %%
3.5-5.0
# Out:
# -1.5

# %%
1.4*2
# Out:
# 2.8

# %%
5/2
# Out:
# 2.5

# %% [markdown]
# ### 연산 기호가 두 개 이상일 경우 일반적인 연산 규칙(‘괄호 안 계산 -> 지수 계산 -> 곱셈과 나눗셈 계산 ->덧셈과 뻘셈 계산’ 순서로 연산
#
# ### 같은 순위의 연산일 경우 왼쪽에서 오른쪽 순서로 계산, 중복된 괄호가 있을 경우 안쪽 괄호부터 계산을
# 따름

# %%
2+3*4
# Out:
# 14

# %%
3/2*4-5/2
# Out:
# 3.5

# %%
10/5+(5-2)*2
# Out:
# 8.0

# %%
(5*4-15)+((5-2) * (9-7))
# Out:
# 11

# %% [markdown]
# ### 파이씬에는 자료의 형식(데이터 타입)을 알려주는 type()이라는 함수

# %%
type(3)
# Out:
# int

# %%
type(1.2)
# Out:
# float

# %% [markdown]
# # 3.2 거듭 제곱과 나머지
#
# ## 숫자A를 기번 곱하는 거듭제곱(Power)

# %%
2*2*2*2*2
# Out:
# 32

# %% [markdown]
# ### 파이썬에서는 거듭제곱을 위한 연산자 ** (두 별표 사이에는 공백이 없어야 함)

# %%
2**5
# Out:
# 32

# %% [markdown]
# ### 정수뿐만 아니라 실수도 거듭제곱

# %%
 1.5 ** 2
# Out:
# 2.25

# %% [markdown]
# ### 거듭제곱의 지수도 정수일 필요가 없음

# %% [markdown]
# ### 파이썬에서 제공하는 수학(math) 라이브러리를 이용하면 거듭제곱，거듭제곱근 외에 다양한 수학 함수

# %%
2** (1/2)
# Out:
# 1.4142135623730951

# %% [markdown]
# ### 나머지를 구하기 위해 파이썬에서는 퍼센트 기호(%)를 이용
# ### 퍼센트 기호(%)를 나머지 연산자(Modulo operator) 라고 함

# %%
13%5
# Out:
# 3

# %%
13//5
# Out:
# 2

# %% [markdown]
# # 3.3과학적 표기법

# %%
3*10**8
# Out:
# 300000000

# %%
3e8
# Out:
# 300000000.0

# %%
1e15
# Out:
# 1000000000000000.0

# %%
1e16
# Out:
# 1e+16

# %%
1e-4
# Out:
# 0.0001

# %%
1e-5
# Out:
# 1e-05

# %% [markdown]
# # 3.4 진수 표현과 변환

# %%
17
# Out:
# 17

# %%
0b10001
# Out:
# 17

# %%
0o21
# Out:
# 17

# %%
0x11
# Out:
# 17

# %%
bin(17)
# Out:
# '0b10001'

# %%
oct(17)
# Out:
# '0o21'

# %%
hex(17)
# Out:
# '0x11'

# %%
type(hex(17))
# Out:
# str

# %% [markdown]
# ### 출력 결과가 숫자가 아니라 문자열임을 나타냄
# ### in(), oct(), hex() 함수를 이용한 출력 결과는 산술 연산에 이용할 수 없음, 진수 변환은 연산이 모두 끝난후에 해야 함

# %%
0b10*0o10+0x10-10
# Out:
# 22

# %%
bin(0b10*0o10+0x10-10)
# Out:
# '0b10110'

# %%
oct(0b10*0o10+0x10-10)
# Out:
# '0o26'

# %%
hex(0b10*0o10+0x10-10)
# Out:
# '0x16'

# %% [markdown]
# #  3.5 논리 연산 및 비교 연산

# %%
print(True)
# Out:
# True

# %%
print(False)
# Out:
# False

# %%
type(True)
# Out:
# bool

# %%
type(False)

# %%
type(True)
# Out:
# bool

# %%
print(True and False)
# Out:
# False

# %%
print(True or False)
# Out:
# True

# %%
print(not True)
# Out:
# False

# %%
print(5==3)
# Out:
# False

# %%
print(5 !=3)
# Out:
# True

# %%
print(5<3)
# Out:
# False

# %%
print(5>3)
# Out:
# True

# %%
print(5<=3)
# Out:
# False

# %%
print(5>=3)
# Out:
# True

# %%
print(1>0 and -2 <0)
# Out:
# True

# %%
print((3<0) and ((-5>0) and (1<5)))
# Out:
# False

# %%
print((3>0) or ((-5>0) and (1>5)))
# Out:
# True

# %%
print(((3>0) or (-5>0)) and ((4>8) or (3<0)))
# Out:
# False

# %%
type("안녕하세요")
# Out:
# str

# %%
type([1,2,3,4])
# Out:
# list
